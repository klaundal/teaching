# %% [markdown]
# # pyAMPS example
#
# I will plot AMPS current maps

# %%
# %matplotlib inline
import pyamps

By, Bz, Vsw, tilt, F107 = -4, -4, 300, 30, 100
m = pyamps.AMPS(Vsw, By, Bz, tilt, F107)
m.plot_currents()
